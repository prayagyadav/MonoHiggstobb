# %%
import hist
import numpy
import matplotlib.pyplot as plt

# %%
hist.Hist.new.Reg(100,-100,100).Double().fill([numpy.random.normal(10,10) for i in range(10000)]).plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f1b1be835b0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]
